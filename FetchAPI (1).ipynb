# %%
import pandas as pd 
import requests

# %%
url = "https://active-jobs-db.p.rapidapi.com/active-ats"


headers = {
    "x-rapidapi-key": "4240baad36msh4bc732820db529dp1d8916jsn21b839efc351",
    "x-rapidapi-host": "active-jobs-db.p.rapidapi.com",
    "Content-Type": "application/json"
}

params = {
    "time_frame": "24h",
    "limit": "10",
    "offset": "0",
    "description_format": "text",
    "title": '"Data Engineer"',
    "location": '"United States" OR "United Kingdom"'
}

response = requests.get(url, headers=headers, params=params)

if response.status_code == 200:
    print("Success! JSON response:")
    print(response.json()) 
else:
    print(f"Error {response.status_code}: {response.text}")
# Out:
# Success! JSON response:
# ...

# %%
if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame(data)
    display(df) 
else:
    print(f"Error {response.status_code}: {response.text}")
# Out:
#            id          date_posted                date_created  \
# 0  2229498706  2026-06-28T00:00:00  2026-06-28T05:20:37.997439
# 1  2229270209  2026-06-27T21:25:37  2026-06-27T21:44:48.797036
# 2  2228674328  2026-06-27T00:00:00  2026-06-27T08:04:06.221257
# 3  2229488016  2026-06-26T00:00:00  2026-06-28T04:43:39.316282
# 4  2228820476  2026-06-26T00:00:00  2026-06-27T11:21:42.278988
# 5  2228738639  2026-06-26T00:00:00  2026-06-27T09:14:00.096503
# 6  2228734887  2026-06-26T00:00:00  2026-06-27T09:11:39.347073
# 7  2228737485  2026-06-25T00:00:00  2026-06-27T09:13:01.646219
# 8  2228732688  2026-06-25T00:00:00  2026-06-27T09:10:19.367873
# 9  2228612217  2026-06-24T18:17:47  2026-06-27T06:37:10.393694
#
#                                                title  \
# 0                                      Data Engineer
# 1                                   Sr Data Engineer
# 2                Data Engineer / Cloud ETL Developer
# 3                                   Data Engineer II
# ...

# %%
df.head(5)
# Out:
#            id          date_posted                date_created  \
# 0  2229498706  2026-06-28T00:00:00  2026-06-28T05:20:37.997439
# 1  2229270209  2026-06-27T21:25:37  2026-06-27T21:44:48.797036
# 2  2228674328  2026-06-27T00:00:00  2026-06-27T08:04:06.221257
# 3  2229488016  2026-06-26T00:00:00  2026-06-28T04:43:39.316282
# 4  2228820476  2026-06-26T00:00:00  2026-06-27T11:21:42.278988
#
#                                  title  \
# 0                        Data Engineer
# 1                     Sr Data Engineer
# 2  Data Engineer / Cloud ETL Developer
# 3                     Data Engineer II
# 4                   Lead Data Engineer
#
#                               organization  \
# 0                                 Overflow
# 1                                      BHE
# 2  General Dynamics Information Technology
# 3                                  Topgolf
# 4                              Capital One
#
#                                     organization_url   date_valid_through  \
# ...

# %%
df.to_csv("active_jobs_data.csv", index=False)
